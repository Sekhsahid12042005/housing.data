# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv("/content/housing.data.csv",sep='\s+',names=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATO','B:1000','CSTATE','MEDV'])
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATO  B:1000  CSTATE  MEDV
# 0      15.3  396.90    4.98  24.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CRIM    506 non-null    float64
#  1   ZN      506 non-null    float64
#  2   INDUS   506 non-null    float64
#  3   CHAS    506 non-null    int64
#  4   NOX     506 non-null    float64
#  5   RM      506 non-null    float64
#  6   AGE     506 non-null    float64
#  7   DIS     506 non-null    float64
#  8   RAD     506 non-null    int64
#  9   TAX     506 non-null    float64
#  10  PTRATO  506 non-null    float64
#  11  B:1000  506 non-null    float64
#  12  CSTATE  506 non-null    float64
#  13  MEDV    506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
data.shape
# Out:
# (506, 14)

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX      PTRATO      B:1000  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
data.max()
# Out:
# CRIM       88.9762
# ZN        100.0000
# INDUS      27.7400
# CHAS        1.0000
# NOX         0.8710
# RM          8.7800
# AGE       100.0000
# DIS        12.1265
# RAD        24.0000
# TAX       711.0000
# PTRATO     22.0000
# B:1000    396.9000
# CSTATE     37.9700
# MEDV       50.0000
# dtype: float64

# %%
data.min()
# Out:
# CRIM        0.00632
# ZN          0.00000
# INDUS       0.46000
# CHAS        0.00000
# NOX         0.38500
# RM          3.56100
# AGE         2.90000
# DIS         1.12960
# RAD         1.00000
# TAX       187.00000
# PTRATO     12.60000
# B:1000      0.32000
# CSTATE      1.73000
# MEDV        5.00000
# dtype: float64

# %%
data.mean()
# Out:
# CRIM        3.613524
# ZN         11.363636
# INDUS      11.136779
# CHAS        0.069170
# NOX         0.554695
# RM          6.284634
# AGE        68.574901
# DIS         3.795043
# RAD         9.549407
# TAX       408.237154
# PTRATO     18.455534
# B:1000    356.674032
# CSTATE     12.653063
# MEDV       22.532806
# dtype: float64

# %%
data.isnull().sum()
# Out:
# CRIM      0
# ZN        0
# INDUS     0
# CHAS      0
# NOX       0
# RM        0
# AGE       0
# DIS       0
# RAD       0
# TAX       0
# PTRATO    0
# B:1000    0
# CSTATE    0
# MEDV      0
# dtype: int64

# %%
data[5:20]
# Out:
#        CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 5   0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222.0
# 6   0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311.0
# 7   0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311.0
# 8   0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311.0
# 9   0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311.0
# 10  0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311.0
# 11  0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311.0
# 12  0.09378  12.5   7.87     0  0.524  5.889   39.0  5.4509    5  311.0
# 13  0.62976   0.0   8.14     0  0.538  5.949   61.8  4.7075    4  307.0
# 14  0.63796   0.0   8.14     0  0.538  6.096   84.5  4.4619    4  307.0
# 15  0.62739   0.0   8.14     0  0.538  5.834   56.5  4.4986    4  307.0
# 16  1.05393   0.0   8.14     0  0.538  5.935   29.3  4.4986    4  307.0
# ...

# %%
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  PTRATO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0    15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0    17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0    17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0    18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0    18.7
#
#    B:1000  CSTATE  MEDV
# 0  396.90    4.98  24.0
# 1  396.90    9.14  21.6
# 2  392.83    4.03  34.7
# 3  394.63    2.94  33.4
# 4  396.90    5.33  36.2

# %%
data.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATO  B:1000  CSTATE  MEDV
# 501    21.0  391.99    9.67  22.4
# 502    21.0  396.90    9.08  20.6
# 503    21.0  396.90    5.64  23.9
# 504    21.0  393.45    6.48  22.0
# 505    21.0  396.90    7.88  11.9

# %%
plt.plot(data)
plt.show()
plt.plot(data,'*')

# %%
n=data['AGE']
plt.plot(n,color='orange',label='age')
plt.legend()
plt.show()

# %%
sns.pairplot(data,hue='DIS')

# %%
sns.barplot(x='CRIM',y='B:1000',data=data)
# Out:
# <Axes: xlabel='CRIM', ylabel='B:1000'>

# %%
sns.jointplot(data=data, x="CRIM", y="DIS", hue="DIS")

# %%
sns.boxplot(data['AGE'])
# Out:
# <Axes: ylabel='AGE'>

# %%
corr=data[['CRIM','RM']].corr()
sns.heatmap(corr)
corr=data[['CRIM','RM']].corr()
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
sns.histplot(data=data,x='AGE')
# Out:
# <Axes: xlabel='AGE', ylabel='Count'>

# %%
sns.displot(x='DIS',data=data)

# %%
sns.scatterplot(x='CRIM',y='CSTATE',data=data,hue='DIS')
# Out:
# <Axes: xlabel='CRIM', ylabel='CSTATE'>
